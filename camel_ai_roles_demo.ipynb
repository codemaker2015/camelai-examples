# %% [markdown]
# # Install CAMEL from source

# %%
# !pip install camel-ai
# Out:
# Collecting camel-ai
#   Downloading camel_ai-0.2.18-py3-none-any.whl.metadata (35 kB)
# Collecting colorama<1,>=0 (from camel-ai)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting curl_cffi==0.6.2 (from camel-ai)
#   Downloading curl_cffi-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting docstring-parser<0.16,>=0.15 (from camel-ai)
#   Downloading docstring_parser-0.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting eval-type-backport==0.2.0 (from camel-ai)
#   Downloading eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpx<0.27.3,>=0.23.0 (from camel-ai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jsonschema<5,>=4 in /usr/local/lib/python3.11/dist-packages (from camel-ai) (4.23.0)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.11/dist-packages (from camel-ai) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai) (1.59.9)
# Collecting pandoc (from camel-ai)
#   Downloading pandoc-2.4.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pathlib<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai) (1.0.1)
# Requirement already satisfied: protobuf<5,>=4 in /usr/local/lib/python3.11/dist-packages (from camel-ai) (4.25.6)
# Collecting pydantic<2.10,>=1.9 (from camel-ai)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai) (6.0.2)
# Collecting tiktoken<0.8.0,>=0.7.0 (from camel-ai)
#   Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from curl_cffi==0.6.2->camel-ai) (1.17.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from curl_cffi==0.6.2->camel-ai) (2024.12.14)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.27.3,>=0.23.0->camel-ai) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.27.3,>=0.23.0->camel-ai) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.27.3,>=0.23.0->camel-ai) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.27.3,>=0.23.0->camel-ai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.27.3,>=0.23.0->camel-ai) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5,>=4->camel-ai) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5,>=4->camel-ai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5,>=4->camel-ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5,>=4->camel-ai) (0.22.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->camel-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->camel-ai) (0.8.2)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->camel-ai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->camel-ai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.10,>=1.9->camel-ai) (0.7.0)
# Collecting pydantic-core==2.23.4 (from pydantic<2.10,>=1.9->camel-ai)
#   Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken<0.8.0,>=0.7.0->camel-ai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken<0.8.0,>=0.7.0->camel-ai) (2.32.3)
# Collecting plumbum (from pandoc->camel-ai)
#   Downloading plumbum-1.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ply in /usr/local/lib/python3.11/dist-packages (from pandoc->camel-ai) (3.11)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12.0->curl_cffi==0.6.2->camel-ai) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken<0.8.0,>=0.7.0->camel-ai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken<0.8.0,>=0.7.0->camel-ai) (2.3.0)
# Downloading camel_ai-0.2.18-py3-none-any.whl (606 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.1/606.1 kB 26.9 MB/s eta 0:00:00
# Downloading curl_cffi-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 39.1 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.7 MB/s eta 0:00:00
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 23.5 MB/s eta 0:00:00
# Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.0 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.4 MB/s eta 0:00:00
# Downloading plumbum-1.9.0-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: pandoc
#   Building wheel for pandoc (setup.py) ... done
#   Created wheel for pandoc: filename=pandoc-2.4-py3-none-any.whl size=34792 sha256=2d9a64f0a0359f6065be88b93cecfecf6a6ab641d174ed53dcf016853179ae42
#   Stored in directory: /root/.cache/pip/wheels/4f/d7/32/c6c9b7b05e852e920fd72174487be3a0f18e633a7adcc303be
# Successfully built pandoc
# Installing collected packages: pydantic-core, plumbum, eval-type-backport, docstring-parser, colorama, tiktoken, pydantic, pandoc, httpx, curl_cffi, camel-ai
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Uninstalling pydantic_core-2.27.2:
#       Successfully uninstalled pydantic_core-2.27.2
#   Attempting uninstall: eval-type-backport
#     Found existing installation: eval_type_backport 0.2.2
#     Uninstalling eval_type_backport-0.2.2:
#       Successfully uninstalled eval_type_backport-0.2.2
#   Attempting uninstall: docstring-parser
#     Found existing installation: docstring_parser 0.16
#     Uninstalling docstring_parser-0.16:
#       Successfully uninstalled docstring_parser-0.16
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# Successfully installed camel-ai-0.2.18 colorama-0.4.6 curl_cffi-0.6.2 docstring-parser-0.15 eval-type-backport-0.2.0 httpx-0.27.2 pandoc-2.4 plumbum-1.9.0 pydantic-2.9.2 pydantic-core-2.23.4 tiktoken-0.7.0

# %% [markdown]
# # Run CAMEL role-playing session

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-proj-xcQxBf5LslO62At..."

# %%
from colorama import Fore

from camel.societies import RolePlaying
from camel.utils import print_text_animated

task_prompt = "Design a custom game using pygame"
print(Fore.YELLOW + f"Original task prompt:\n{task_prompt}\n")
role_play_session = RolePlaying("Computer Programmer", "Gamer", task_prompt=task_prompt)
print(Fore.CYAN + f"Specified task prompt:\n{role_play_session.task_prompt}\n")

chat_turn_limit, n = 2, 0
input_msg = role_play_session.init_chat()
while n < chat_turn_limit:
    n += 1
    assistant_response, user_response = role_play_session.step(input_msg)
    print_text_animated(Fore.BLUE +f"AI User:\n\n{user_response.msg.content}\n")
    print_text_animated(Fore.GREEN + "AI Assistant:\n\n"f"{assistant_response.msg.content}\n")

    if "CAMEL_TASK_DONE" in user_response.msg.content:
        break

    input_msg = assistant_response.msg
# Out:
# Original task prompt:
# Design a custom game using pygame
#
# Specified task prompt:
# Design a 2D platformer game using Pygame where players control a time-traveling hero who navigates through different historical eras. Include unique enemies, collectible artifacts, and puzzles that require manipulating time to progress. Implement a scoring system based on artifacts collected and time taken to complete each level.
#
# AI User:
#
# Instruction: Set up a new Pygame project and create a basic game window.
# Input: None
# AI Assistant:
#
# Solution: To set up a new Pygame project and create a basic game window, follow these steps:
#
# 1. **Install Pygame**: If you haven't installed Pygame yet, you can do so using pip. Open your terminal or command prompt and run:
#    ```bash
#    pip install pygame
#    ```
#
# 2. **Create a new Python file**: Create a new Python file for your project, for example, `time_travel_platformer.py`.
#
# 3. **Set up the basic game window**: In your Python file, you will need to import Pygame, initialize it, and create a game window. Below is a sample code snippet to achieve this:
#
#    ```python
#    import pygame
#    import sys
#
#    # Initialize Pygame
#    pygame.init()
#
#    # Set up display
#    WIDTH, HEIGHT = 800, 600
#    screen = pygame.display.set_mode((WIDTH, HEIGHT))
#    pygame.display.set_caption("Time Traveling Hero")
#
#    # Main game loop
#    running = True
#    while running:
#        for event in pygame.event.get():
#            if event.type == pygame.QUIT:
#                running = False
#
#        # Fill the screen with a color (RGB)
#        screen.fill((135, 206, 250))  # Light blue background
#
#        # Update the display
#        pygame.display.flip()
#
#    # Quit Pygame
#    pygame.quit()
#    sys.exit()
#    ```
#
# 4. **Run the game**: Save your file and run it. You should see a window pop up with a light blue background. You can close the window by clicking the close button.
#
# ### Explanation:
# - **Importing Pygame**: This allows us to use the Pygame library functions.
# - **Initializing Pygame**: `pygame.init()` initializes all the Pygame modules.
# - **Setting up the display**: We define the width and height of the window and create it using `pygame.display.set_mode()`. We also set a title for the window using `pygame.display.set_caption()`.
# - **Main game loop**: This loop keeps the game running until the user decides to quit. It checks for events (like closing the window) and updates the display.
# - **Filling the screen**: We fill the screen with a specific color using `screen.fill()`.
# - **Updating the display**: `pygame.display.flip()` updates the contents of the entire display.
#
# Next request.
# AI User:
#
# Instruction: Create a player character that can move left and right using keyboard inputs.
# Input: None
# AI Assistant:
#
# Solution: To create a player character that can move left and right using keyboard inputs in your Pygame project, you will need to define a player class, handle keyboard events, and update the player's position based on those inputs. Below is an updated version of your previous code that includes a player character.
#
# 1. **Define the Player Class**: This class will represent the player character and handle its movement.
#
# 2. **Update the Game Loop**: Modify the game loop to include player movement.
#
# Here’s the updated code:
#
# ```python
# import pygame
# import sys
#
# # Initialize Pygame
# pygame.init()
#
# # Set up display
# WIDTH, HEIGHT = 800, 600
# screen = pygame.display.set_mode((WIDTH, HEIGHT))
# pygame.display.set_caption("Time Traveling Hero")
#
# # Define colors
# LIGHT_BLUE = (135, 206, 250)
# WHITE = (255, 255, 255)
#
# # Player class
# class Player:
#     def __init__(self):
#         self.rect = pygame.Rect(WIDTH // 2, HEIGHT - 50, 50, 50)  # Player's position and size
#         self.speed = 5  # Speed of the player
#
#     def move(self, keys):
#         if keys[pygame.K_LEFT]:  # Move left
#             self.rect.x -= self.speed
#         if keys[pygame.K_RIGHT]:  # Move right
#             self.rect.x += self.speed
#
#         # Keep the player within the screen bounds
#         if self.rect.x < 0:
#             self.rect.x = 0
#         if self.rect.x > WIDTH - self.rect.width:
#             self.rect.x = WIDTH - self.rect.width
#
#     def draw(self, surface):
#         pygame.draw.rect(surface, WHITE, self.rect)  # Draw the player as a white rectangle
#
# # Create a player instance
# player = Player()
#
# # Main game loop
# running = True
# while running:
#     for event in pygame.event.get():
#         if event.type == pygame.QUIT:
#             running = False
#
#     # Get the state of all keys
#     keys = pygame.key.get_pressed()
#     player.move(keys)  # Move the player based on key inputs
#
#     # Fill the screen with a color
#     screen.fill(LIGHT_BLUE)
#
#     # Draw the player
#     player.draw(screen)
#
#     # Update the display
#     pygame.display.flip()
#
# # Quit Pygame
# pygame.quit()
# sys.exit()
# ```
#
# ### Explanation:
# - **Player Class**:
#   - The `Player` class has an `__init__` method that initializes the player's rectangle (`self.rect`) and speed.
#   - The `move` method checks for left and right arrow key presses and updates the player's position accordingly. It also ensures that the player stays within the screen bounds.
#   - The `draw` method draws the player as a white rectangle on the screen.
#
# - **Game Loop**:
#   - The game loop now retrieves the current state of the keyboard using `pygame.key.get_pressed()`, which returns a list of boolean values indicating whether each key is pressed.
#   - The `move` method of the player instance is called with the current key states to update the player's position.
#   - The player is drawn on the screen after filling the background.
#
# Next request.
